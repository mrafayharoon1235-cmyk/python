# %% [markdown]
# # Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
print("Muhammad Rafay Haroon")
print("Haroon ur Rasheed")
print("2014 6 February")
# Out:
# Muhammad Rafay Haroon
# Haroon ur Rasheed
# 2014 6 February

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
print("I Study in class 6.")
print("My school name is usman public school system.")
# Out:
# I Study in class 6.
# My school name is usman public school system.

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
A=5 
B=9
print(A+B)
print(A-B)
print( A*B)
print(B/A)
# Out:
# 14
# -4
# 45
# 1.8

# %% [markdown]
# 4. Completes the following steps of small task:
#     - Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
#     - Mention Variable of Total Marks and assign 300 to it
#     - Calculate Percentage

# %%
English=82
Islamiat=78
Math=90
TotalMarks =300
GainMarks = English + Islamiat + Math
print(GainMarks / TotalMarks * 100)
# Out:
# 83.33333333333334
